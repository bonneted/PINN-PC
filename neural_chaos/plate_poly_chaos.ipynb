# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import os
import time
import scienceplots
plt.style.use(['science','grid'])

# %% [markdown]
# ### Simulate the stifness coefficients as lognormal random fields

# %%
from scipy.special import kv, gamma

def exp_kernel(distance,i=2):
    """Exponential correlation function."""
    return np.exp(-distance**i)

def matern_kernel(distance, nu=1.5, l=1.0):
    """Matérn correlation function."""
    factor = np.sqrt(2*nu) * distance / l
    if np.isscalar(distance):
        return 1.0 if distance == 0 else (2**(1-nu) / gamma(nu)) * (factor**nu) * kv(nu, factor)
    result = (2**(1-nu) / gamma(nu)) * (factor**nu) * kv(nu, factor)
    result[distance == 0] = 1.0
    return result

kernel = exp_kernel # matern_kernel or exp_kernel

def compute_correlation_matrix(grid,kernel, bx,by):
    """Compute the correlation matrix for a 2D grid."""
    N = grid.shape[0]
    C = np.zeros((N, N))
    for i in range(N):
        for j in range(N):
            d = np.sqrt(((grid[i, 0] - grid[j, 0])/bx)**2 + ((grid[i, 1] - grid[j, 1])/by)**2)
            C[i, j] = kernel(d)
    return C


def KL_expansion(grid, kernel, C_param,truncation_order):
    """Compute the KL expansion."""
    N = grid.shape[0]
    mu = C_param[0]
    sigma = C_param[1]
    bx = C_param[2]
    by = C_param[3]
    C = compute_correlation_matrix(grid, kernel, bx, by)
    eig_values, eig_vectors = np.linalg.eigh(C)
    # Sort eigenvalues and eigenvectors
    idx = eig_values.argsort()[::-1]
    eig_values = eig_values[idx]
    eig_vectors = eig_vectors[:, idx]

    return eig_values[:truncation_order], eig_vectors[:, :truncation_order]

C11param = [ 1.55, 0.129, 75, 100]   # = [ mu, sigma , bx, by] 
C33param = [ 0.316, 0.027, 100, 75]

# Parameters
N = 20 # Discretization of the domain for C11 and C33
Lmax = 100

# Create 2D grid
x = np.linspace(0, Lmax, N)
y = np.linspace(0, Lmax, N)
X, Y = np.meshgrid(x, y)
grid = np.column_stack((X.ravel(), Y.ravel()))

truncation_order = N**2 # Keep all modes (= number of grid points)

# Spectral decomposition
load_KL = False
if load_KL:
    kl_modes = np.load('one_sample/kl_modes.npy',allow_pickle=True).item()
    KL_C11_val = kl_modes['eig_values_C11']
    KL_C11 = kl_modes['eig_vectors_C11']
    KL_C33_val = kl_modes['eig_values_C33']
    KL_C33 = kl_modes['eig_vectors_C33']
else:
    KL_C11_val, KL_C11 = KL_expansion(grid, kernel, C11param, truncation_order)
    KL_C33_val, KL_C33 = KL_expansion(grid, kernel, C33param, truncation_order)

    #thresholding at 0 eigenvalues
    KL_C11_val[KL_C11_val<0]=0
    KL_C33_val[KL_C33_val<0]=0

    kl_modes = {'eig_values_C11':KL_C11_val, 'eig_vectors_C11':KL_C11, 'eig_values_C33':KL_C33_val, 'eig_vectors_C33':KL_C33}
    # np.save('kl_modes.npy',kl_modes)

def C_from_xi(xi, eig_values, eig_vectors, C_param):
    """Compute the Lognormal field from the KL expansion."""
    N = int(np.sqrt(eig_vectors.shape[0]))
    Nsim = xi.shape[0]
    XC = eig_vectors @ (np.sqrt(eig_values) * xi).T
    C = np.exp(C_param[0] + C_param[1] * XC)
    return C

def dC_from_xi(xi, KL_values, KL_vectors, KL_d_vectors, C_param):
    """Compute the gradient of the Gaussian Random Field from the KL expansion."""
    N = int(np.sqrt(KL_vectors.shape[0]))
    Nsim = xi.shape[0]
    XC = KL_vectors @ (np.sqrt(KL_values) * xi).T
    dXC_dx = KL_d_vectors[...,0] @ (np.sqrt(KL_values) * xi).T
    dXC_dy = KL_d_vectors[...,1] @ (np.sqrt(KL_values) * xi).T
    dC_dx = C_param[1] * dXC_dx * np.exp(C_param[0] + C_param[1] * XC)
    dC_dy = C_param[1] * dXC_dy * np.exp(C_param[0] + C_param[1] * XC)
    return np.hstack((dC_dx, dC_dy))

# %%
#plotting utility function
def pcolor_plot(AX, X, Y, C, title,colormap="viridis",set_axis = 'off',**kwargs):
    ## plot the pcolor plot of the given data C on the given axis AX with the given title and optional colorbar limits cmin and cmax
    if len(kwargs) == 0:
        im = AX.pcolor(X, Y, C, cmap=colormap,shading='auto')
    else:
        cmin = kwargs["cmin"]
        cmax = kwargs["cmax"]
        im = AX.pcolor(X, Y, C, cmap=colormap, vmin=cmin, vmax=cmax,shading='auto')
    AX.set_aspect("equal", "box")
    AX.axis(set_axis)
    AX.set_title(title, fontsize=14)
    return im
#Truncation of the KL expansion based on the explained variance

explained_variance = np.cumsum(KL_C11_val) / np.sum(KL_C11_val)
fig = plt.figure(figsize=(4, 4))
n_orders = 20
plt.plot(np.arange(0, n_orders + 1), [0] + list(explained_variance[:n_orders]*100), marker='.')
plt.xlabel(r'Order of the KL expansion', fontsize=12)
plt.ylabel(r'Explained Variance (\%)', fontsize=12)
# plt.title('Explained Variance vs. Order of KL Expansion')
plt.tight_layout()
fig.savefig('figures/KL_explained_variance_C11.pdf')

# Propose truncation order based on a threshold
threshold = 0.95  # Example threshold for 99% explained variance
truncation_order = np.argmax(explained_variance >= threshold) + 1
print(f"The {truncation_order} first modes explain {threshold*100:.2f}% of the variance.")

# Plot first modes
fig, ax = plt.subplots(2, 2, figsize=(4, 4))
for i in range(4):
    im = pcolor_plot(ax.flatten()[i], X, Y, KL_C11[:, i].reshape(N,N), f"Mode {i+1}")
plt.tight_layout()
# plt.suptitle('First 8 Modes of the KL Expansion for C11', fontsize=20, y=1.15)
fig.savefig('figures/KL_modes_C11.pdf')
# Out:
# The 4 first modes explain 95.00% of the variance.

# %% [markdown]
# ## Implementation of the PINN-PC framework

# %%
# The code has been tested with both JAX and PyTorch backends. It should work with TensorFlow/Paddle as well but has not been tested.
# JAX is recommended for higher computational performance (x10-x20 faster than PyTorch in our implementation).
import deepxde as dde
from jax.scipy.interpolate import RegularGridInterpolator
import jax.numpy as jnp
import jax

# Define functions
sin = dde.backend.sin
cos = dde.backend.cos
stack = dde.backend.stack

net_type = ["spinn","pinn"][0]
Lmax = 100.0
pstress = 0.1

if net_type == "spinn":
    dde.config.set_default_autodiff("forward")

N = 20 # Discretization of the domain for C11 and C33
Lmax = 100

# Create 2D grid
x = np.linspace(0, Lmax, N)
y = np.linspace(0, Lmax, N)
X, Y = np.meshgrid(x, y)
grid = np.column_stack((X.ravel(), Y.ravel()))

n_xi_samples =10
truncation_for_param_generation = 10

# Simulate Gaussian Random Field using K-L expansion
xi_C11 = np.random.randn(n_xi_samples,truncation_for_param_generation)
xi_C33 = np.random.randn(n_xi_samples,truncation_for_param_generation)
# xi_C11 = np.zeros_like(xi_C11) # for testing without randomness
# xi_C33 = np.zeros_like(xi_C33) # for testing without randomness
xi_train = np.concatenate([xi_C11,xi_C33],axis=1)

# Spectral decomposition
KL_C11_val, KL_C11 = KL_expansion(grid, exp_kernel, C11param, truncation_for_param_generation)
KL_C33_val, KL_C33 = KL_expansion(grid, exp_kernel, C33param, truncation_for_param_generation)

KL_C11_fun = RegularGridInterpolator((x, y),KL_C11.reshape(N,N, truncation_for_param_generation))
KL_C33_fun = RegularGridInterpolator((x, y),KL_C33.reshape(N,N, truncation_for_param_generation))

KL_dC11_fun = jax.jacrev(lambda x: KL_C11_fun(x).squeeze())
KL_dC33_fun = jax.jacrev(lambda x: KL_C33_fun(x).squeeze())

n_pde = 64
X_mesh_pde, Y_mesh_pde = np.meshgrid(np.linspace(0, Lmax, n_pde), np.linspace(0, Lmax, n_pde), indexing="ij")
X_pde = np.vstack((X_mesh_pde.flatten(), Y_mesh_pde.flatten())).T

KL_C11_pde = KL_C11_fun(X_pde)  # (n_xi_samples, n_pde^2)
KL_C33_pde = KL_C33_fun(X_pde)  # (n_xi_samples, n_pde^2)

KL_dC11_pde = jax.vmap(KL_dC11_fun)(X_pde) 
KL_dC33_pde = jax.vmap(KL_dC33_fun)(X_pde)


# Compute random coefficients
C11 = C_from_xi(xi_C11, KL_C11_val, KL_C11, C11param)
C33 = C_from_xi(xi_C33, KL_C33_val, KL_C33, C33param)


C11_fun = RegularGridInterpolator((x, y),C11.reshape(N,N, n_xi_samples))
C33_fun = RegularGridInterpolator((x, y),C33.reshape(N,N, n_xi_samples))

truncation_order = 4
xi_train = np.concatenate([xi_C11[:,:truncation_order],xi_C33[:,:truncation_order]],axis=1)
# Truncate the KL expansion
# KL_C11_val = KL_C11_val[:truncation_order]
# KL_C11 = KL_C11[:,:truncation_order]
# KL_C33_val = KL_C33_val[:truncation_order]
# KL_C33 = KL_C33[:,:truncation_order]


# dC11_fun = jax.jacrev(lambda x: C11_fun(x).squeeze())
# dC33_fun = jax.jacrev(lambda x: C33_fun(x).squeeze())

# n_pde = 100
# X_mesh_pde, Y_mesh_pde = np.meshgrid(np.linspace(0, Lmax, n_pde), np.linspace(0, Lmax, n_pde), indexing="ij")
# X_pde = np.vstack((X_mesh_pde.flatten(), Y_mesh_pde.flatten())).T

# C11_pde = C11_fun(X_pde)  # (n_xi_samples, n_pde^2)
# C33_pde = C33_fun(X_pde)  # (n_xi_samples, n_pde^2)

# dC11_pde = jax.vmap(dC11_fun)(X_pde) 
# dC33_pde = jax.vmap(dC33_fun)(X_pde)
# print("C11_vals shape:", C11_pde.shape)
# print("dC11_vals shape:", dC11_pde.shape)

def C_from_xi(xi, eig_values, eig_vectors, C_param):
    """Compute the Lognormal field from the KL expansion."""
    XC = eig_vectors @ (jnp.sqrt(eig_values) * xi).T
    C = jnp.exp(C_param[0] + C_param[1] * XC)
    return C

def dC_from_xi(xi, KL_values, KL_vectors, KL_d_vectors, C_param):
    """Compute the gradient of the Gaussian Random Field from the KL expansion."""
    XC = KL_vectors @ (jnp.sqrt(KL_values) * xi).T
    dXC_dx = KL_d_vectors[...,0] @ (jnp.sqrt(KL_values) * xi).T
    dXC_dy = KL_d_vectors[...,1] @ (jnp.sqrt(KL_values) * xi).T
    dC_dx = C_param[1] * dXC_dx * jnp.exp(C_param[0] + C_param[1] * XC)
    dC_dy = C_param[1] * dXC_dy * jnp.exp(C_param[0] + C_param[1] * XC)
    return jnp.stack((dC_dx, dC_dy), axis=-1)
# Out:
# Set the default automatic differentiation to forward mode.

# %%
Exx_mean_fem = 0.02571187493951528
Eyy_mean_fem = -0.010741097568904246

def transform_coords(x):
    """
    For SPINN, if the input x is provided as a list of 1D arrays (e.g., [X_coords, Y_coords]),
    this function creates a 2D meshgrid and stacks the results into a 2D coordinate array.
    """
    x_mesh = [x_.ravel() for x_ in jnp.meshgrid(jnp.atleast_1d(x[0].squeeze()), jnp.atleast_1d(x[1].squeeze()), indexing="ij")]
    return dde.backend.stack(x_mesh, axis=-1)

def solution_fn(x):
    if net_type == "spinn":
        x = transform_coords(x)
    Ux = Exx_mean_fem*x[:,0]
    Uy = Eyy_mean_fem*x[:,1]
    return np.stack([Ux,Uy],axis=1)

# %%
geom = dde.geometry.Rectangle([0, 0], [Lmax, Lmax])
BC_type = ["hard", "soft"][0]
coord_normalization = True
# x_max = 1.0 if coord_normalization else Lmax
num_bc_points = 25

bc_linspace = np.linspace(0, Lmax, num_bc_points).reshape(-1,1)
if net_type != "spinn":
    bc_0 = np.zeros_like(bc_linspace)
    bc_Lmax = Lmax*np.ones_like(bc_linspace)
else:
    bc_0 = np.array([0]).reshape(-1,1)
    bc_Lmax = np.array([Lmax]).reshape(-1,1)

bc_point_left = [bc_0, bc_linspace]
bc_point_right = [bc_Lmax, bc_linspace]
bc_point_bottom = [bc_linspace, bc_0]
bc_point_top = [bc_linspace, bc_Lmax]

if net_type != "spinn":
    bc_point_left = np.hstack(bc_point_left)
    bc_point_right = np.hstack(bc_point_right)
    bc_point_bottom = np.hstack(bc_point_bottom)
    bc_point_top = np.hstack(bc_point_top)

bc_point_all = [bc_point_left, bc_point_right, bc_point_bottom, bc_point_top]

# Soft Boundary Conditions

# def u_xi(x, u_fun, xi):
#     if x.ndim == 1:
#         x = x.reshape(1, -1)
#     output = u_fun(x)    
#     Ux_mean = output[:,0:1] * x[:, 0:1] / Lmax
#     Ux_coefs = output[:,1:2*truncation_order+1] * x[:, 0:1] / Lmax
#     Uy_mean = output[:,2*truncation_order+1:2*truncation_order+2] * x[:, 1:2] / Lmax 
#     Uy_coefs = output[:,2*truncation_order+2:4*truncation_order+2] * x[:, 1:2] / Lmax 

#     Ux = (Ux_mean + Ux_coefs @ xi.T)
#     Uy = (Uy_mean + Uy_coefs @ xi.T)
#     return stack([Ux, Uy], axis=1)

def u_xi(x, u_fun, xi):
    if x.ndim == 1:
        x = x.reshape(1, -1)
    output = u_fun(x) 
    ones_column = jnp.ones((xi.shape[0], 1))
    xi_plus_mean = jnp.hstack((ones_column, xi))

    Ux_coefs = output[:,:2*truncation_order+1] * x[:, 0:1] / Lmax
    Uy_coefs = output[:,2*truncation_order+1:] * x[:, 1:2] / Lmax

    Ux = (Ux_coefs @ xi_plus_mean.T) 
    Uy = (Uy_coefs @ xi_plus_mean.T)
    return stack([Ux, Uy], axis=1)

def u_xi_test(x, u_fun, xi):
    if x.ndim == 1:
        x = x.reshape(1, -1)
    Ux = u_fun(x)[:,0:1] * x[:, 0:1]
    Uy = u_fun(x)[:,1:2] * x[:, 1:2]
    return stack([Ux, Uy], axis=1)

def u_mean_metric(y_true, y_pred):
    # Ux_mean = y_pred[:,0:1]
    # Uy_mean = y_pred[:,truncation_order:truncation_order+1]

    # U_pred = stack([Ux_mean, Uy_mean], axis=1).squeeze()
    # return dde.metrics.mean_squared_error(y_true, U_pred)
    return dde.metrics.mean_squared_error(y_true, y_pred)

def S_from_output(x, f,X):
    if net_type == "spinn":
        x = transform_coords(x)

    def u_xi_batch(x):
        return u_xi(x, f[1], xi_train).T.squeeze()
    
    C11_vals_bc = C11_fun(x)  # (n_bc, n_xi_samples)
    C33_vals_bc = C33_fun(x)  # (n_bc, n_xi_samples)
    
    df = jax.jacfwd(u_xi_batch)
    df_x = jax.vmap(df)(x)
    # df_x = np.repeat(df_x[:,np.newaxis, ...], n_xi_samples, axis=1) # (n_xi_batch, n_points, 2, 2)
    E_xx = df_x[..., 0, 0]
    E_yy = df_x[..., 1, 1]
    E_xy = 0.5 * (df_x[..., 0, 1] + df_x[..., 1, 0])

    S_xx = C11_vals_bc * (E_xx + E_yy) - 2*C33_vals_bc * E_yy
    S_yy = C11_vals_bc * (E_xx + E_yy) - 2*C33_vals_bc * E_xx
    S_xy = C33_vals_bc * E_xy

    return stack((S_xx, S_yy, S_xy), axis=1)

ux_left_bc = dde.PointSetOperatorBC(bc_point_left,0,lambda x, f, X: f[:, 0])
uy_bottom_bc = dde.PointSetOperatorBC(bc_point_bottom,0,lambda x, f, X: f[:, 1])
sxx_right_bc = dde.PointSetOperatorBC(bc_point_right,0,lambda x, f, X: S_from_output(x, f, X)[:, 0:1]-pstress)
syy_top_bc = dde.PointSetOperatorBC(bc_point_top,0,lambda x, f, X: S_from_output(x, f, X)[:, 1:2])
sxy_bc = [dde.PointSetOperatorBC(bc_point,0,lambda x, f, X: S_from_output(x, f, X)[:, 2]) for bc_point in bc_point_all]

bcs = [ux_left_bc, uy_bottom_bc] if BC_type == "soft" else []
bcs += [sxx_right_bc,syy_top_bc]
bcs += sxy_bc

def compute_strain(x, f):
    def u_xi_batch(x):
        return u_xi(x, f[1], xi_train).T.squeeze()
    df = jax.jacfwd(lambda x: u_xi_batch(x))
    df_x = jax.vmap(df)(x).squeeze()
    # Strain components:
    E_xx = df_x[..., 0, 0]
    E_yy = df_x[..., 1, 1]
    E_xy = 0.5 * (df_x[..., 0, 1] + df_x[..., 1, 0])
    return jnp.stack([E_xx, E_yy, E_xy], axis=1).squeeze()  # shape (3,)

def pde(x, f):
    # Optionally transform coordinates.
    if net_type == "spinn":
        x = transform_coords(x)  # x: shape (n_points, 2)

    # --- Compute C11 and C33 values and their spatial derivatives ---
    # C11_vals: shape (n_points, n_xi_samples)
    # U_C11 = np.random.randn(1,truncation_for_param_generation)
    # U_C33 = np.random.randn(1,truncation_for_param_generation)


    # Compute random coefficients
    C11_pde = C_from_xi(xi_C11, KL_C11_val, KL_C11_pde, C11param)
    C33_pde = C_from_xi(xi_C33, KL_C33_val, KL_C33_pde, C33param)

    dC11_pde = dC_from_xi(xi_C11, KL_C11_val, KL_C11_pde, KL_dC11_pde, C11param)
    dC33_pde = dC_from_xi(xi_C33, KL_C33_val, KL_C33_pde, KL_dC33_pde, C33param)

    # --- Compute strain components and their spatial derivatives ---
    # strains: shape (n_points, 3)
    strains = jax.vmap(lambda x_single: compute_strain(x_single.reshape(1,-1), f))(x)
    # jac_strain: shape (n_points, 3, 2)
    jac_strain = jax.vmap(lambda x_single: jax.jacfwd(lambda z: compute_strain(z, f))(x_single.reshape(1,-1)).squeeze())(x)
    # Extract derivatives:
    dExx_dx = jac_strain[:, :, 0, 0]  # derivative of E_xx with respect to x
    dExx_dy = jac_strain[:, :, 0, 1]  # derivative of E_xx with respect to y
    dEyy_dx = jac_strain[:, :, 1, 0]  # derivative of E_yy with respect to x
    dEyy_dy = jac_strain[:, :, 1, 1]  # derivative of E_yy with respect to y
    dExy_dx = jac_strain[:, :, 2, 0]  # derivative of E_xy with respect to x
    dExy_dy = jac_strain[:, :, 2, 1]  # derivative of E_xy with respect to y

    Exx = strains[:, :, 0]  # shape (n_points,)
    Eyy = strains[:, :, 1]
    Exy = strains[:, :, 2]

    Mx = dC11_pde[:, :, 0] * (Exx + Eyy) + C11_pde * (dExx_dx + dEyy_dx) - 2*dC33_pde[:, :, 0] * Eyy - 2*C33_pde * dEyy_dx + dC33_pde[:, :, 1] * Exy + C33_pde * dExy_dy
    My = dC11_pde[:, :, 1] * (Exx + Eyy) + C11_pde * (dExx_dy + dEyy_dy) - 2*dC33_pde[:, :, 1] * Exx - 2*C33_pde * dExx_dy + dC33_pde[:, :,0] * Exy + C33_pde * dExy_dx

    return Mx, My

# %%
data = dde.data.PDE(
    geom,
    pde,
    bcs,
    num_domain=n_pde**2 if net_type == "spinn" else 500,
    num_boundary=0,
    # solution=solution_fn,
    num_test=n_pde**2,
    is_SPINN=(net_type == "spinn"),
)

activation = "tanh"
initializer = "Glorot uniform"
if net_type == "spinn":
    layers = [2] + [16] * 2 + [4] + [2+truncation_order*4] # 2*truncation_order (U_C11, U_C33) for both Ux and Uy
    net = dde.nn.SPINN(layers, activation, initializer)
else:
    layers = [2, [40] * (2+truncation_order*2), [40] * (2+truncation_order*2), [40] * (2+truncation_order*2), (2+truncation_order*2)]
    net = dde.nn.PFNN(layers, activation, initializer)


def input_scaling(x):
    """
    Scale the input coordinates to the range [0, 1].
    """
    if isinstance(x, list):
        return [x_el / Lmax for x_el in x]
    else:
        return x / Lmax
    
if coord_normalization:
    net.apply_feature_transform(input_scaling)

model = dde.Model(data, net)
model.compile("adam", lr=0.001, #metrics=[u_mean_metric], 
              loss_weights=[1]*8)
# Out:
# Compiling model...
# 'compile' took 0.085977 s

# %%
from jax.flatten_util import ravel_pytree
import jax

X_input = [np.linspace(0, Lmax, n_pde).reshape(-1, 1)] * 2
X_mesh_pde, Y_mesh_pde = np.meshgrid(X_input[0], X_input[1])
if net_type != "spinn":
    X_input = np.vstack((X_mesh_pde.flatten(), Y_mesh_pde.flatten())).T
    
def loss_function(params,comp=0,inputs=[bc_point_right]+[bc_point_top]+bc_point_all+[X_input]):
    return model.outputs_losses_train(params, inputs, None)[1][comp]

n_loss = len(model.loss_weights)

def calc_loss_weights(model):
    loss_grads = [1]*n_loss

    for i in range(n_loss):
        grad_fn = jax.grad(lambda params,comp=i: loss_function(params,comp))
        grads = grad_fn(model.params)[0]
        flattened_grad = ravel_pytree(list(grads.values())[0])[0]
        loss_grads[i] = jnp.linalg.norm(flattened_grad)

    loss_grads = jnp.array(loss_grads)
    loss_weights_grads = jnp.sum(loss_grads)/loss_grads # Caution: ad-hoc sqrt
    return loss_weights_grads, loss_grads

loss_weights_grads, loss_grads = calc_loss_weights(model)
new_loss_weights = [w * g for w, g in zip(model.loss_weights, loss_weights_grads)]
model.compile("adam", lr=0.001,# metrics=[u_mean_metric],
              loss_weights=new_loss_weights)
# Out:
# Compiling model...
# 'compile' took 0.394799 s

# %%
losshistory, train_state = model.train(iterations=20000, display_every=1000)
# Out:
# Training model...
#
# 48697     [5.45e-04, 4.53e-04, 1.59e-04, 8.40e-05, 1.87e-06, 1.95e-06, 1.36e-06, 3.13e-06]    [5.45e-04, 4.53e-04, 1.59e-04, 8.40e-05, 1.87e-06, 1.95e-06, 1.36e-06, 3.13e-06]    []
# 49000     [5.43e-04, 4.52e-04, 1.63e-04, 8.85e-05, 3.60e-06, 2.79e-06, 1.71e-06, 4.66e-06]    [5.43e-04, 4.52e-04, 1.63e-04, 8.85e-05, 3.60e-06, 2.79e-06, 1.71e-06, 4.66e-06]    []
# 50000     [5.44e-04, 4.52e-04, 1.61e-04, 8.45e-05, 2.08e-06, 2.23e-06, 1.53e-06, 3.54e-06]    [5.44e-04, 4.52e-04, 1.61e-04, 8.45e-05, 2.08e-06, 2.23e-06, 1.53e-06, 3.54e-06]    []
# 51000     [5.45e-04, 4.53e-04, 1.59e-04, 8.33e-05, 2.03e-06, 2.01e-06, 1.34e-06, 3.22e-06]    [5.45e-04, 4.53e-04, 1.59e-04, 8.33e-05, 2.03e-06, 2.01e-06, 1.34e-06, 3.22e-06]    []
# 52000     [5.48e-04, 4.54e-04, 1.59e-04, 8.22e-05, 3.43e-06, 3.46e-06, 1.91e-06, 4.21e-06]    [5.48e-04, 4.54e-04, 1.59e-04, 8.22e-05, 3.43e-06, 3.46e-06, 1.91e-06, 4.21e-06]    []
# ...

# %%
from matplotlib.colors import ListedColormap

cmap = plt.get_cmap('viridis')
num_colors = 30
color_values = [cmap(i) for i in np.linspace(0, 1, num_colors)]
cmap = ListedColormap(color_values)

xi_plot = xi_train #np.random.randn(10000, truncation_order*2) #xi_train


X_input = [np.linspace(0, Lmax, 100).reshape(-1, 1)] * 2
X_mesh_pde, Y_mesh_pde = np.meshgrid(X_input[0], X_input[1], indexing="ij")
X_input_mesh = np.vstack((X_mesh_pde.flatten(), Y_mesh_pde.flatten())).T
if net_type != "spinn":
    X_input = X_input_mesh
Y_pred = model.predict([X_input])[0]
Y_pred_fun = lambda x: model.net.apply(model.net.params, x)

def u_from_y(x, y, xi):
    Ux_mean = y[:,0:1] * x[:, 0:1] / Lmax
    Ux_coefs = y[:,1:2*truncation_order+1] * x[:, 0:1] / Lmax
    Uy_mean = y[:,2*truncation_order+1:2*truncation_order+2] * x[:, 1:2] / Lmax
    Uy_coefs = y[:,2*truncation_order+2:] * x[:, 1:2] / Lmax

    Ux = (Ux_mean + Ux_coefs @ xi.T) 
    Uy = (Uy_mean + Uy_coefs @ xi.T)
    return stack([Ux, Uy], axis=1)

U_pred = u_from_y(X_input_mesh,Y_pred, xi_plot)
U_pred_mean = np.mean(U_pred, axis=-1)
# U_pred_mean = Y_pred*X_input_mesh

Ux_pred_mean = U_pred_mean[:,0].reshape(X_mesh_pde.shape)
# Ux_pred_mean = Y_pred[:,0:1].reshape(X_mesh_pde.shape) * X_mesh_pde#/Lmax

Uy_pred_mean = U_pred_mean[:,1].reshape(X_mesh_pde.shape)
# Uy_pred_mean = Y_pred[:,2*truncation_order+1:2*truncation_order+2].reshape(X_mesh_pde.shape) * Y_mesh_pde#/Lmax
U_pred_std = np.std(U_pred, axis=-1)
Ux_pred_std = U_pred_std[:,0].reshape(X_mesh_pde.shape)
Uy_pred_std = U_pred_std[:,1].reshape(X_mesh_pde.shape)


Y_true = solution_fn(X_input)
Ux_true = Y_true[:,0].reshape(X_mesh_pde.shape)
Uy_true = Y_true[:,1].reshape(X_mesh_pde.shape)

fields = [Ux_pred_mean, Uy_pred_mean, Ux_pred_std, Uy_pred_std]
fields_true = [Ux_true, Uy_true, np.zeros_like(Ux_true), np.zeros_like(Uy_true)]
field_names = ["Ux-mean", "Uy-mean", "Ux-std", "Uy-std"]

fig,ax = plt.subplots(3, len(fields), figsize=(3*len(fields),3*2.5))

for i in range(len(fields)):
    cmax = np.max(fields_true[i])
    cmin = np.min(fields_true[i])
    im = pcolor_plot(ax[0][i], X_mesh_pde, Y_mesh_pde, fields_true[i], field_names[i] + " (True)",colormap=cmap,cmin=cmin,cmax=cmax)
    fig.colorbar(im, ax=ax[0][i])
    
    im = pcolor_plot(ax[1][i], X_mesh_pde, Y_mesh_pde, fields[i], field_names[i],colormap=cmap)#,cmin=cmin,cmax=cmax)
    fig.colorbar(im, ax=ax[1][i])

    diff = fields[i] - fields_true[i]
    cmax = np.max(np.abs(diff))
    im = pcolor_plot(ax[2][i], X_mesh_pde, Y_mesh_pde, diff, field_names[i] + " Error",colormap="coolwarm",cmin=-cmax,cmax=cmax)
    fig.colorbar(im, ax=ax[2][i])

    for i in range(3):
        ax[i][0].set_aspect("equal", "box")
        ax[i][0].axis("off")

fig.tight_layout()

# %%
fields = [Ux_pred_mean, Uy_pred_mean, Ux_pred_std, Uy_pred_std]
fields_names = ["Ux-mean", "Uy-mean", "Ux-std", "Uy-std"]
fig, axs = plt.subplots(2, 2, figsize=(7.4, 6), dpi=300)
for i, ax in enumerate(axs.T.flatten()):
    cmap_i = cmap if i > 1 else "copper" 
    im = pcolor_plot(ax, X_mesh_pde, Y_mesh_pde, fields[i], field_names[i],colormap=cmap_i, set_axis="on")
    fig.colorbar(im, ax=ax)

# %%
S_pred = np.mean(S_from_output(X_input,(Y_pred,Y_pred_fun),X_input), axis=-1)
Sxx_pred = S_pred[:,0].reshape(X_mesh_pde.shape).T
Syy_pred = S_pred[:,1].reshape(X_mesh_pde.shape).T
Sxy_pred = S_pred[:,2].reshape(X_mesh_pde.shape).T

Sxx_true = pstress*np.ones_like(Sxx_pred)
Syy_true = np.zeros_like(Syy_pred)
Sxy_true = np.zeros_like(Sxy_pred)

fields = [Sxx_pred, Syy_pred, Sxy_pred]
fields_true = [Sxx_true, Syy_true, Sxy_true]
field_names = ["Sxx", "Syy", "Sxy"]

fig,ax = plt.subplots(3, len(fields), figsize=(3*len(fields),3*2.5))

for i in range(len(fields)):
    cmax = np.max(fields_true[i])
    cmin = np.min(fields_true[i])
    im = pcolor_plot(ax[0][i], X_mesh_pde, Y_mesh_pde, fields_true[i], field_names[i] + " (True)",colormap=cmap,cmin=cmin,cmax=cmax)
    fig.colorbar(im, ax=ax[0][i])
    
    im = pcolor_plot(ax[1][i], X_mesh_pde, Y_mesh_pde, fields[i], field_names[i],colormap=cmap)#,cmin=cmin,cmax=cmax)
    fig.colorbar(im, ax=ax[1][i])

    diff = fields[i] - fields_true[i]
    cmax = np.max(np.abs(diff))
    im = pcolor_plot(ax[2][i], X_mesh_pde, Y_mesh_pde, diff, field_names[i] + " Error",colormap="coolwarm",cmin=-cmax,cmax=cmax)
    fig.colorbar(im, ax=ax[2][i])

    for i in range(3):
        ax[i][0].set_aspect("equal", "box")
        ax[i][0].axis("off")

fig.tight_layout()

# %%
def jacobian(f, x, i, j):
    jacobian_val = dde.grad.jacobian(f, x, i=i, j=j)
    return jacobian_val[0] if dde.backend.backend_name == "jax" else jacobian_val

def U_from_output(f,variable, mean_or_coefs):
    """
    net output columns: Ux_mean, Ux_coefs, Uy_mean, Uy_coefs
    mean of size 1 and coefs of size truncation_order
    """
    i_begin = 0 if mean_or_coefs == "mean" else 1
    i_end = 1 if mean_or_coefs == "mean" else truncation_order

    if variable == "Uy":
        i_begin += truncation_order
        i_end += truncation_order
    return (f[0][:,i_begin:i_end], lambda x: f[1](x)[:,i_begin:i_end])


def pde(x, f):
    indices = np.random.permutation(xi_train.shape[0])[:n_xi_batch]
    xi_batch = xi_train[indices]


    Ux_mean = U_from_output(f,"Ux","mean")
    Uy_mean = U_from_output(f,"Uy","mean")
    Ux_coefs = U_from_output(f,"Ux","coefs")
    Uy_coefs = U_from_output(f,"Uy","coefs")

    Ux = Ux_mean + xi_batch @ Ux_coefs.T
    Uy = Uy_mean + xi_batch @ Uy_coefs.T

    momentum_x = 0
    momentum_y = 0
    for i in range(n_xi_batch):
        xi_sample = xi_batch[i]
        Ux_i = Ux[i]
        Uy_i = Uy[i]
        C11_i = C11_fun[i](x)
        C33_i = C33_fun[i](x)
        Exx_i = jacobian(Ux_i, x, 0, 0)
        Eyy_i = jacobian(Uy_i, x, 0, 1)
        Exy_i = [jacobian(Ux_i, x, 0, 1)[0] + jacobian(Uy_i, x, 0, 0)[0], lambda x: jacobian(Ux_i, x, 0, 1)[1] + jacobian(Uy_i, x, 0, 0)[1]]
        Sxx_i = [C11_i*(Exx_i[0] + Eyy_i[0]) - 2*C33_i*Eyy_i[0], lambda x: C11_i*(Exx_i[1](x) + Eyy_i[1](x)) - 2*C33_i*Eyy_i[1](x)]
        Syy_i = [C11_i*(Exx_i[0] + Eyy_i[0]) - 2*C33_i*Exx_i[0], lambda x: C11_i*(Exx_i[1](x) + Eyy_i[1](x)) - 2*C33_i*Exx_i[1](x)]
        Sxy_i = [C33_i*Exy_i[0], lambda x: C33_i*Exy_i[1](x)]
        Sxx_x_i = jacobian(Sxx_i, x, 0, 0)  
        Syy_y_i = jacobian(Syy_i, x, 0, 1)
        Sxy_x_i = jacobian(Sxy_i, x, 0, 0)
        Sxy_y_i = jacobian(Sxy_i, x, 0, 1)
        momentum_x += Sxx_x_i + Sxy_y_i
        momentum_y += Syy_y_i + Sxy_x_i

    
    momentum_x /= n_xi_batch
    momentum_y /= n_xi_batch

    return [momentum_x, momentum_y]

# %%
def pde(x, f):
    indices = np.random.permutation(xi_train.shape[0])[:n_xi_batch]
    xi_batch = xi_train[indices]


    Ux_mean = U_from_output(f,"Ux","mean")
    Uy_mean = U_from_output(f,"Uy","mean")
    Ux_coefs = U_from_output(f,"Ux","coefs")
    Uy_coefs = U_from_output(f,"Uy","coefs")

    Exx_mean = jacobian(Ux_mean, x, 0, 0)
    Eyy_mean = jacobian(Uy_mean, x, 0, 1)
    Exy_mean = [jacobian(Ux_mean, x, 0, 1)[0] + jacobian(Uy_mean, x, 0, 0)[0], lambda x: jacobian(Ux_mean, x, 0, 1)[1] + jacobian(Uy_mean, x, 0, 0)[1]]

    Exx_coefs = jacobian(Ux_coefs, x, 0, 0)
    Eyy_coefs = jacobian(Uy_coefs, x, 0, 1)
    Exy_coefs = [jacobian(Ux_coefs, x, 0, 1)[0] + jacobian(Uy_coefs, x, 0, 0)[0], lambda x: jacobian(Ux_coefs, x, 0, 1)[1] + jacobian(Uy_coefs, x, 0, 0)[1]]

    Sxx_mean = [C11(x)*(Exx_mean[0] + Eyy_mean[0]) - 2*C33(x)*Eyy_mean[0], lambda x: C11(x)*(Exx_mean[1](x) + Eyy_mean[1](x)) - 2*C33(x)*Eyy_mean[1](x)]
    Syy_mean = [C11(x)*(Exx_mean[0] + Eyy_mean[0]) - 2*C33(x)*Exx_mean[0], lambda x: C11(x)*(Exx_mean[1](x) + Eyy_mean[1](x)) - 2*C33(x)*Exx_mean[1](x)]
    Sxy_mean = [C33(x)*Exy_mean[0], lambda x: C33(x)*Exy_mean[1](x)]

    Sxx_coefs = [C11(x)*(Exx_coefs[0] + Eyy_coefs[0]) - 2*C33(x)*Eyy_coefs[0], lambda x: C11(x)*(Exx_coefs[1](x) + Eyy_coefs[1](x)) - 2*C33(x)*Eyy_coefs[1](x)]
    Syy_coefs = [C11(x)*(Exx_coefs[0] + Eyy_coefs[0]) - 2*C33(x)*Exx_coefs[0], lambda x: C11(x)*(Exx_coefs[1](x) + Eyy_coefs[1](x)) - 2*C33(x)*Exx_coefs[1](x)]
    Sxy_coefs = [C33(x)*Exy_coefs[0], lambda x: C33(x)*Exy_coefs[1](x)]

    Sxx_x_mean = jacobian(Sxx_mean, x, 0, 0)
    Syy_y_mean = jacobian(Syy_mean, x, 0, 1)
    Sxy_x_mean = jacobian(Sxy_mean, x, 0, 0)
    Sxy_y_mean = jacobian(Sxy_mean, x, 0, 1)
    Sxx_x_coefs = []
    Syy_y_coefs = []
    Sxy_x_coefs = []
    Sxy_y_coefs = []
    for i in range(truncation_order):
        Sxx_x_coefs.append(jacobian(Sxx_coefs, x, 0, 0)[0][:,i])
        Syy_y_coefs.append(jacobian(Syy_coefs, x, 0, 1)[0][:,i])
        Sxy_x_coefs.append(jacobian(Sxy_coefs, x, 0, 0)[0][:,i])
        Sxy_y_coefs.append(jacobian(Sxy_coefs, x, 0, 1)[0][:,i])
    Sxx_x_coefs = dde.backend.stack(Sxx_x_coefs, 1).squeeze()
    Syy_y_coefs = dde.backend.stack(Syy_y_coefs, 1).squeeze()
    Sxy_x_coefs = dde.backend.stack(Sxy_x_coefs, 1).squeeze()
    Sxy_y_coefs = dde.backend.stack(Sxy_y_coefs, 1).squeeze()

    Sxx_x = Sxx_x_mean + xi_batch @ Sxx_x_coefs.T
    Syy_y = Syy_y_mean + xi_batch @ Syy_y_coefs.T
    Sxy_x = Sxy_x_mean + xi_batch @ Sxy_x_coefs.T
    Sxy_y = Sxy_y_mean + xi_batch @ Sxy_y_coefs.T

    momentum_x = Sxx_x + Sxy_y
    momentum_y = Syy_y + Sxy_x

    

    return [momentum_x, momentum_y]

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import time
import skopt


# Ensure reproducibility
torch.manual_seed(0)

# Set the device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# device = "cpu"
def grad_i(Y,X,i):
    #calculate the partial derivative of y with respect to x_i
    return torch.autograd.grad(Y, X, grad_outputs=torch.ones_like(Y), create_graph=True)[0][:, None, i].flatten()
print("Using GPU:", torch.cuda.is_available())
# Out:
# Using GPU: True

# %%
def E_nn(U,X):
    #calculate the strain given the displacement
    # u is the output of the NN, a tensor of shape (N,2)
    Exx = grad_i(U[0],X,0)
    Eyy = grad_i(U[1],X,1)
    Exy = 0.5 * (grad_i(U[1],X,0) +grad_i(U[0],X,1))
    return [Exx, Eyy, Exy]

def S_nn(E, C11, C33):
    Exx, Eyy, Exy = E
    Sxx = C11 * (Exx + Eyy) - 2*C33 * Eyy
    Syy = C11 * (Exx + Eyy) - 2*C33 * Exx
    Sxy = 2*C33 * Exy

    return [Sxx, Syy, Sxy]

def compute_PDE(X, E, C_data):

    C11, dC11_pde[:,0], dC11_dy,C33,dC33_pde[:,0], dC33_pde[:,1] = C_data
    Exx, Eyy, Exy = E 

    # Sxx, Syy, Sxy = S_nn(E, C11, C33)
    # dSxx_dx = grad_i(Sxx,X,0)
    # dSyy_dy = grad_i(Syy,X,1)
    # dSxy_dx = grad_i(Sxy,X,0)
    # dSxy_dy = grad_i(Sxy,X,1)

    # Mx = dSxx_dx + dSxy_dy
    # My = dSyy_dy + dSxy_dx 
    dExx_dx = grad_i(Exx,X,0)
    dExx_dy = grad_i(Exx,X,1)
    dEyy_dx = grad_i(Eyy,X,0)
    dEyy_dy = grad_i(Eyy,X,1)
    dExy_dx = grad_i(Exy,X,0)
    dExy_dy = grad_i(Exy,X,1)
 
    Mx = dC11_pde[:,0] * (Exx + Eyy) + C11 * (dExx_dx + dEyy_dx) - 2*dC33_pde[:,0] * Eyy - 2*C33 * dEyy_dx + 2*dC33_pde[:,1] * Exy + 2*C33 * dExy_dy
    My = dC11_dy * (Exx + Eyy) + C11 * (dExx_dy + dEyy_dy) - 2*dC33_pde[:,1] * Exx - 2*C33 * dExx_dy + 2*dC33_pde[:,0] * Exy + 2*C33 * dExy_dx

    return [Mx, My]


def Enforce_BC(x,Ux,Uy):

    Ux = Ux*x[:,0]
    Uy = Uy*x[:,1]
    return [Ux,Uy]


def static_sampling(domain,n_samples, sampling_strat):
    """Generate a static sampling strategy for the domain.
    "random","LHS" are stochastic
    "grid","Halton","Hammersley","Sobol" are deterministic
    Parameters
    ----------
    domain:[[XMIN, XMAX], [YMIN, YMAX]]
        The domain of the problem.
    n_samples: int
        The number of samples.
    sampling_strat: str
        The sampling strategy.
    Returns
    -------
    X: numpy.ndarray
        The generated samples.
    """
    if sampling_strat == "Random":
        X = np.random.uniform(domain[0][0], domain[0][1], n_samples)
        Y = np.random.uniform(domain[1][0], domain[1][1], n_samples)
        X = np.hstack((X.reshape(-1, 1), Y.reshape(-1, 1)))
        return X
    elif sampling_strat == "Grid":
        X = np.linspace(domain[0][0], domain[0][1], int(np.sqrt(n_samples)))
        Y = np.linspace(domain[1][0], domain[1][1], int(np.sqrt(n_samples)))
        X, Y = np.meshgrid(X, Y)
        X = X.reshape(-1, 1)
        Y = Y.reshape(-1, 1)
        X = np.hstack((X, Y))
        return X
     
    elif sampling_strat == "LHS":
        sampler = skopt.sampler.Lhs(lhs_type="centered", criterion="maximin", iterations=1000)
    elif sampling_strat == "Halton":
        sampler = skopt.sampler.Halton(min_skip=-1, max_skip=-1)
    elif sampling_strat == "Hammersley":
        sampler = skopt.sampler.Hammersly(min_skip=-1, max_skip=-1)
    elif sampling_strat == "Sobol":
        # Remove the first point [0, 0, ...] and the second point [0.5, 0.5, ...], which
        # are too special and may cause some error.
        sampler = skopt.sampler.Sobol(skip=0, randomize=False)
        return np.array(sampler.generate(domain, n_samples + 2)[2:])
    return np.array(sampler.generate(domain, n_samples))

def adaptative_sampling(self,domain,n_samples,loss_function,existing_sample=None, k=1, c=1):
    
    if existing_sample is None:
        X_previous = torch.tensor(static_sampling(domain,n_samples, "Hammersley"), dtype=torch.float32, device=self.device)
    else:
        X_previous = existing_sample

    X = static_sampling(domain,100000, "Random")
    X_torch = torch.tensor(X, dtype=torch.float32, device=device)
    X_torch.requires_grad = True
    loss = loss_function(X_torch).detach().cpu().numpy()
    loss += min(loss)

    err_eq = np.power(loss, k) / np.power(loss, k).mean() + c
    err_eq_normalized = (err_eq / sum(err_eq))
    X_ids = np.random.choice(a=len(X), size=int(n_samples/10), replace=False, p=err_eq_normalized)
    X_new =  torch.tensor(X[X_ids,:], dtype=torch.float32, device=self.device)
    return torch.cat((X_previous,X_new))

# %%
def hermite_polynomial(order, xi):
    """Compute the Hermite polynomial of a given order for xi."""
    if order == 0:
        return torch.ones_like(xi)
    elif order == 1:
        return xi
    else:
        H0 = torch.ones_like(xi)
        H1 = xi
        for _ in range(2, order + 1):
            H_next = xi * H1 - (order - 1) * H0
            H0, H1 = H1, H_next
        return H1

def generate_pce_basis(xi, max_order):
    """Generate PCE basis up to a given order for xi."""
    basis = []
    for order in range(max_order + 1):
        basis.append(hermite_polynomial(order, xi))
    return torch.stack(basis, dim=-1)

class MeanNN(nn.Module):
    """Neural network to approximate the mean function."""
    def __init__(self, input_dim, hidden_dim=100, output_dim=1):
        super(MeanNN, self).__init__()
        self.fc1 = nn.Linear(input_dim, hidden_dim)
        self.fc2 = nn.Linear(hidden_dim, hidden_dim)
        self.fc3 = nn.Linear(hidden_dim, output_dim)
        self.tanh = nn.Tanh()

    def forward(self, x):
        x = self.tanh(self.fc1(x))
        x = self.tanh(self.fc2(x))
        x = self.fc3(x)
        return x


class CoefficientNN(nn.Module):
    """Neural network to approximate the coefficients of the PCE."""
    def __init__(self, input_dim, hidden_dim=32, output_dim=None):
        super(CoefficientNN, self).__init__()
        self.fc1 = nn.Linear(input_dim, hidden_dim)
        self.fc2 = nn.Linear(hidden_dim, hidden_dim)
        self.fc3 = nn.Linear(hidden_dim, output_dim)
        self.tanh = nn.Tanh()

    def forward(self, x):
        x = self.tanh(self.fc1(x))
        x = self.tanh(self.fc2(x))
        x = self.fc3(x)
        return x
    
def U_nn(x, xi, Ux_mean, Ux_coeffs, Uy_mean, Uy_coeffs, Enforce_BC,N=27**2):
    """Compute the total predicted u."""
    x_unique = x[:N,:]

    pce_basis = hermite_polynomial(1, xi)
    Ux = Ux_mean(x).flatten() + (Ux_coeffs(x_unique) @ pce_basis.T).T.flatten()  
    Uy = Uy_mean(x).flatten() + (Uy_coeffs(x_unique) @ pce_basis.T).T.flatten()
    Ux, Uy = Enforce_BC(x,Ux,Uy)
    return [Ux, Uy]

def l2_regularization(model):
    l2_reg = None
    for W in model.parameters():
        if l2_reg is None:
            l2_reg = W.norm(2)
        else:
            l2_reg = l2_reg + W.norm(2)
    return l2_reg

def U_exact(X,delta=0):
    Ux = 0.025712*X[:,0]+delta*torch.cos(np.pi*X[:,0]/Lmax)
    Uy = -0.010741*X[:,1]+delta*torch.cos(np.pi*X[:,1]/Lmax)
    return [Ux,Uy]

def compute_loss(x_pde,x_bcs, xi, Ux_mean, Ux_coeffs, Uy_mean, Uy_coeffs, C_data, C_data_bc, batch_size,pstress=0.1,N=27):

    N_sim = xi.size(0)
    indices = torch.randperm(N_sim)[:batch_size]
    xi_batch = xi[indices]

    U_pde = U_nn(x_pde, xi_batch, Ux_mean, Ux_coeffs, Uy_mean, Uy_coeffs, Enforce_BC,N**2)
    E_pde = E_nn(U_pde,x_pde)


    # Compute the stress
    pde_indices = np.repeat(indices*N**2,N**2) + np.tile(np.array(range(N**2)),batch_size)
    C_data_batch = [C[pde_indices] for C in C_data]

    bc_indices = np.repeat(indices*N,N) + np.tile(np.array(range(N)),batch_size)
    C_data_batch_bc = [C[bc_indices] for C in C_data_bc]

    Mx,My = compute_PDE(x_pde, E_pde, C_data_batch)

    pde_loss = torch.mean((Mx**2 + My**2))
    # Boundary Conditions Loss on stress
    U_bc_stress = U_nn(x_bcs[0], xi_batch, Ux_mean, Ux_coeffs, Uy_mean, Uy_coeffs, Enforce_BC,N)
    E_bc_stress = E_nn(U_bc_stress,x_bcs[0])
    S_bc_stress = S_nn(E_bc_stress, C_data_batch_bc[0], C_data_batch_bc[1])
    bc_loss_stress = torch.mean((S_bc_stress[0] - pstress)**2)
    
    U_bc_free = U_nn(x_bcs[1], xi_batch, Ux_mean, Ux_coeffs, Uy_mean, Uy_coeffs, Enforce_BC,N)
    E_bc_free = E_nn(U_bc_free,x_bcs[1])
    S_bc_free = S_nn(E_bc_free, C_data_batch_bc[2], C_data_batch_bc[3])
    bc_loss_free = torch.mean((S_bc_free[1])**2)


    # Combine the losses
    bc_loss = bc_loss_stress + bc_loss_free
    U_pde_exact = U_exact(x_pde)
    residual_loss = torch.mean((U_pde[0] - U_pde_exact[0])**2 + (U_pde[1] - U_pde_exact[1])**2)
    
    return pde_loss, bc_loss, residual_loss

# %%
def train(Ux_mean, Ux_coeffs, Uy_mean, Uy_coeffs, xi, C_data, C_data_bc, batch_size=100, epochs=1000, lr=0.001, lambda_reg=1e-4,lambda_bc=1, N = 27,sampling = 'Grid',pstress=0.1,opt='Adam',print_every=100,models_to_train_type = ['mean','coeffs']):
    device = xi.device
    t_start = time.perf_counter()
    x_pde = torch.tensor(static_sampling([[0, Lmax], [0, Lmax]], N**2, sampling)).float().to(device).repeat(batch_size,1)
    x_pde.requires_grad = True

    x_bc_stress = torch.ones((N,2))*Lmax
    x_bc_stress[:,1] = torch.linspace(0,Lmax,N).float()
    x_bc_stress = x_bc_stress.to(device).repeat(batch_size,1)
    x_bc_stress.requires_grad = True
    

    x_bc_free = torch.ones((N,2))*Lmax
    x_bc_free[:,0] = torch.linspace(0,Lmax,N).float()
    x_bc_free = x_bc_free.to(device).repeat(batch_size,1)
    x_bc_free.requires_grad = True

    x_bcs = [x_bc_stress,x_bc_free]

    models_to_train = []
    parameters_to_train = []
    if 'mean' in models_to_train_type:
        models_to_train += [Ux_mean,Uy_mean]
        parameters_to_train += list(Ux_mean.parameters()) + list(Uy_mean.parameters()) 

    if 'coeffs' in models_to_train_type:
        models_to_train += [Ux_coeffs,Uy_coeffs]
        parameters_to_train += list(Ux_coeffs.parameters()) + list(Uy_coeffs.parameters())
    # parameters_to_train = [model.parameters() for model in models_to_train]

    if opt == 'Adam':
        optimizer = torch.optim.Adam(parameters_to_train, lr=lr)

        for epoch in range(epochs):
            optimizer.zero_grad()
            
            pde_loss,bc_loss,residual_loss = compute_loss(x_pde,x_bcs, xi, Ux_mean, Ux_coeffs, Uy_mean, Uy_coeffs,C_data,C_data_bc, batch_size,pstress=pstress,N=N)
            l2_reg = torch.sum(torch.stack([l2_regularization(model) for model in models_to_train]))
            loss = pde_loss + lambda_reg*l2_reg + lambda_bc*bc_loss #+ residual_loss
            loss.backward()
            optimizer.step()
            
            # Print progress
            if epoch % print_every == 0:
                print(f"Epoch {epoch}, Loss: {loss.item():.3e}, PDE loss: {pde_loss.item():.3e}, BC loss: {bc_loss.item():.3e},Residual: {residual_loss.item():.3e}, l2 reg: {l2_reg.item():.3e}, Elapsed time: {time.perf_counter()-t_start:.0f}")

    elif opt == 'LBFGS':
        optimizer = torch.optim.LBFGS(parameters_to_train, lr=lr, max_iter=20, max_eval=None, tolerance_grad=1e-05, tolerance_change=1e-09, history_size=100, line_search_fn=None)
        # optimizer = torch.optim.LBFGS(list(Ux_mean.parameters())+list(Uy_mean.parameters()), lr=lr)
        def closure():
            optimizer.zero_grad()
            pde_loss,bc_loss,residual_loss = compute_loss(x_pde,x_bcs, xi, Ux_mean, Ux_coeffs, Uy_mean, Uy_coeffs,C_data,C_data_bc, batch_size,pstress=pstress,N=N)
            l2_reg = torch.sum(torch.stack([l2_regularization(model) for model in models_to_train]))
            loss = pde_loss + lambda_reg*l2_reg + lambda_bc*bc_loss
            loss.backward()
            return loss
        for epoch in range(epochs):
            optimizer.step(closure)
            # Print progress
            if epoch % print_every == 0:
                pde_loss,bc_loss,residual_loss = compute_loss(x_pde,x_bcs, xi, Ux_mean, Ux_coeffs, Uy_mean, Uy_coeffs,C_data, batch_size,pstress=pstress,N=N)
                l2_reg = torch.sum(torch.stack([l2_regularization(model) for model in models_to_train]))
                print(f"Epoch {epoch}, Loss: {closure().item():.3e}, PDE loss: {pde_loss.item():.3e}, BC loss: {bc_loss.item():.3e},Residual loss: {residual_loss.item():.3e}, l2 reg: {l2_reg.item():.3e}, Elapsed time: {time.perf_counter()-t_start:.0f}")
    
    pde_loss,bc_loss,residual_loss = compute_loss(x_pde,x_bcs, xi, Ux_mean, Ux_coeffs, Uy_mean, Uy_coeffs,C_data,C_data_bc, batch_size,pstress=pstress,N=N)
    l2_reg = torch.sum(torch.stack([l2_regularization(model) for model in models_to_train]))
    loss = pde_loss + lambda_reg*l2_reg + lambda_bc*bc_loss

    print(f"Epoch {epoch}, Loss: {loss.item():.3e}, PDE loss: {pde_loss.item():.3e}, BC loss: {bc_loss.item():.3e},Residual loss: {residual_loss.item():.3e}, l2 reg: {l2_reg.item():.3e}, Elapsed time: {time.perf_counter()-t_start:.0f}")
    return Ux_mean, Ux_coeffs, Uy_mean, Uy_coeffs

# %%
Lmax = 100
N = 27  # Grid of size N x N
Nsim = 1000  # Number of simulations
truncation_order = 8

# Create 2D grid
x = np.linspace(0, Lmax, N)
y = np.linspace(0, Lmax, N)
X, Y = np.meshgrid(x, y)
grid = np.column_stack((X.ravel(), Y.ravel()))

# C11param = [ 1.55, 0, 50, 50]   # = [ mu, sigma , bx, by]
# C33param = [ 0.316, 0, 50, 50]

C11param = [ 1.55, 0.129, 50, 50]   # = [ mu, sigma , bx, by]
C33param = [ 0.316, 0.027, 50, 50]

KL_C11_val, KL_C11 = KL_expansion(grid, kernel, C11param, truncation_order)
KL_C33_val, KL_C33 = KL_expansion(grid, kernel, C33param, truncation_order)


# Simulate Gaussian Random Field using K-L expansion
xi_C11 = np.random.randn(Nsim,truncation_order)
xi_C33 = np.random.randn(Nsim,truncation_order)
xi = torch.cat((torch.tensor(xi_C11).float(),torch.tensor(xi_C33).float()),dim=1).to(device)

# Compute random coefficients
C11 = C_from_xi(xi_C11, KL_C11_val, KL_C11, C11param)
C33 = C_from_xi(xi_C33, KL_C33_val, KL_C33, C33param)

# Calculate the derivatives of the eigenfunctions
eig_vectors_C11_dx, eig_vectors_C11_dy = calculate_derivatives(KL_C11.reshape((N,N,truncation_order)))
eig_vectors_C11_dx = eig_vectors_C11_dx.reshape((N**2,truncation_order))
eig_vectors_C11_dy = eig_vectors_C11_dy.reshape((N**2,truncation_order))
eig_vectors_C33_dx, eig_vectors_C33_dy = calculate_derivatives(KL_C33.reshape((N,N,truncation_order)))
eig_vectors_C33_dx = eig_vectors_C33_dx.reshape((N**2,truncation_order))
eig_vectors_C33_dy = eig_vectors_C33_dy.reshape((N**2,truncation_order))

C11_bc_stress = C11[:,-1,:]
C33_bc_stress = C33[:,-1,:]
C11_bc_free = C11[-1,:,:]
C33_bc_free = C33[-1,:,:]

C_data_bc = (C11_bc_stress, C33_bc_stress, C11_bc_free, C33_bc_free)
C_data_bc = [C.reshape((N,Nsim)).T.ravel() for C in C_data_bc]
C_data_bc = [torch.tensor(C).float().to(device) for C in C_data_bc]

dC11, dC11_dy = dC_from_xi(xi_C11, KL_C11_val, KL_C11, eig_vectors_C11_dx, eig_vectors_C11_dy, C11param)
dC33, dC33_pde[:,1] = dC_from_xi(xi_C33, KL_C33_val, KL_C33, eig_vectors_C33_dx, eig_vectors_C33_dy, C33param)

C_data = (C11, dC11, dC11_dy, C33, dC33, dC33_pde[:,1])
C_data = [C.reshape((N**2, Nsim)).T.ravel() for C in C_data]
C_data = [torch.tensor(C).float().to(device) for C in C_data]

# Models, Loss, and Optimizer
Ux_mean = MeanNN(input_dim=2).to(device)
Ux_coeffs = CoefficientNN(input_dim=2, output_dim=truncation_order*2).to(device)
Uy_mean = MeanNN(input_dim=2).to(device)
Uy_coeffs = CoefficientNN(input_dim=2, output_dim=truncation_order*2).to(device)

# %%
xi_C11 = np.zeros_like(xi_C11) # for testing --> should be removed
xi_C33 = np.zeros_like(xi_C33) # for testing --> should be removed


load_models = False
save_folder = "saved_models"
suffix = "_mean"
if load_models:
    Ux_mean.load_state_dict(torch.load(os.path.join(save_folder, f"Ux_mean{suffix}.pt"), map_location=torch.device(device)))
#     Ux_coeffs.load_state_dict(torch.load(os.path.join(save_folder, f"Ux_coeffs{suffix}.pt"), map_location=torch.device(device)))
    Uy_mean.load_state_dict(torch.load(os.path.join(save_folder, f"Uy_mean{suffix}.pt"), map_location=torch.device(device)))
#     Uy_coeffs.load_state_dict(torch.load(os.path.join(save_folder, f"Uy_coeffs{suffix}.pt"), map_location=torch.device(device)))
    print("Models loaded.")
    
# Training
batch_size = 1
opt = ['Adam','LBFGS'][0]
learning_rate = 1e-2
lambda_bc = 1e0
lambda_reg = 1e-3
epochs = 1000
print_every = 100
models_to_train_type = ['mean']
Ux_mean, Ux_coeffs, Uy_mean, Uy_coeffs = train(Ux_mean, Ux_coeffs, Uy_mean, Uy_coeffs, xi, C_data, C_data_bc, batch_size=batch_size, epochs=epochs, lr=learning_rate, lambda_reg=lambda_reg,lambda_bc=lambda_bc,N = 27,sampling = 'Grid',opt=opt,print_every=print_every,models_to_train_type=models_to_train_type)
# Out:
# Epoch 0, Loss: 4.914e+01, PDE loss: 6.248e+00, BC loss: 4.286e+01,Residual: 1.684e+03, l2 reg: 3.370e+01, Elapsed time: 0
# Epoch 100, Loss: 2.923e+00, PDE loss: 5.753e-01, BC loss: 2.311e+00,Residual: 5.816e+02, l2 reg: 3.657e+01, Elapsed time: 9
# Epoch 200, Loss: 4.294e+00, PDE loss: 2.783e-01, BC loss: 3.980e+00,Residual: 3.619e+02, l2 reg: 3.623e+01, Elapsed time: 20
# Epoch 300, Loss: 9.674e+01, PDE loss: 9.351e-01, BC loss: 9.577e+01,Residual: 5.208e+03, l2 reg: 3.668e+01, Elapsed time: 29
# Epoch 400, Loss: 3.462e+00, PDE loss: 3.601e-01, BC loss: 3.065e+00,Residual: 7.810e+02, l2 reg: 3.764e+01, Elapsed time: 37
# Epoch 500, Loss: 8.385e+00, PDE loss: 2.102e-01, BC loss: 8.137e+00,Residual: 7.996e+02, l2 reg: 3.791e+01, Elapsed time: 47
# Epoch 600, Loss: 1.368e+01, PDE loss: 3.035e-01, BC loss: 1.334e+01,Residual: 9.144e+02, l2 reg: 3.907e+01, Elapsed time: 56
# ...

# %%
import os

# Create the folder if it doesn't exist
save_folder = "saved_models"
if not os.path.exists(save_folder):
    os.makedirs(save_folder)

suffix = '_mean'
save_models = True
if save_models:
    torch.save(Ux_mean.state_dict(), os.path.join(save_folder, f"Ux_mean{suffix}.pt"))
    torch.save(Ux_coeffs.state_dict(), os.path.join(save_folder, f"Ux_coeffs{suffix}.pt"))
    torch.save(Uy_mean.state_dict(), os.path.join(save_folder, f"Uy_mean{suffix}.pt"))
    torch.save(Uy_coeffs.state_dict(), os.path.join(save_folder, f"Uy_coeffs{suffix}.pt"))
    print("Models saved.")
# Out:
# Models saved.

# %%
#load matlab monte carlo data
import scipy.io as sio
Ux_samples = sio.loadmat('./matlab/Ux_samples.mat')['ux_data']
Uy_samples = sio.loadmat('./matlab/Uy_samples.mat')['uy_data']
N_mc = int(np.sqrt(Ux_samples.shape[0]))
Nsim_mc = Ux_samples.shape[1]
Ux_samples = np.transpose(Ux_samples.reshape((N_mc,N_mc,Nsim_mc)),(1,0,2))
Uy_samples = np.transpose(Uy_samples.reshape((N_mc,N_mc,Nsim_mc)),(1,0,2))

U_mean_mc_torch = torch.tensor([np.mean(Ux_samples,axis=2).squeeze(),np.mean(Uy_samples,axis=2).squeeze()]).float().to(device)
U_std_mc_torch = torch.tensor([np.std(Ux_samples,axis=2).squeeze(),np.std(Uy_samples,axis=2).squeeze()]).float().to(device)
U_mean_mc = lambda x: U_mean_mc_torch
U_std_mc = lambda x: U_std_mc_torch
# Out:
# C:\Users\u0150568\AppData\Local\Temp\8\ipykernel_113208\3492285243.py:10: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at ..\torch\csrc\utils\tensor_new.cpp:248.)
#   U_mean_mc_torch = torch.tensor([np.mean(Ux_samples,axis=2).squeeze(),np.mean(Uy_samples,axis=2).squeeze()]).float().to(device)

# %%
# plotting utilities

def pcolor_plot(AX, X, Y, C, title,colormap="copper",**kwargs):
    ## plot the pcolor plot of the given data C on the given axis AX with the given title and optional colorbar limits cmin and cmax
    if len(kwargs) == 0:
        im = AX.pcolor(X, Y, C, cmap=colormap,shading='auto')
    else:
        cmin = kwargs["cmin"]
        cmax = kwargs["cmax"]
        im = AX.pcolor(X, Y, C, cmap=colormap, vmin=cmin, vmax=cmax,shading='auto')
    AX.axis("equal")
    AX.axis("off")
    AX.set_title(title, fontsize=14)
    return im

def plot_field(domain,model,output_func=None,V_exact=None,plot_diff=False,N=27,fields_name=None,dpi=100):

    X = np.linspace(domain[0][0], domain[0][1], N)
    Y = np.linspace(domain[1][0], domain[1][1], N)
    Xgrid, Ygrid = np.meshgrid(X, Y)
    Xinput = np.hstack((Xgrid.reshape(-1, 1), Ygrid.reshape(-1, 1)))
    Xinput = torch.tensor(Xinput).float().to(device)
    Xinput.requires_grad = True

    plotify = lambda x: x.reshape(Xgrid.shape).cpu().detach().numpy()

    if output_func is not None:
        V_nn = output_func(model(Xinput))
    else:
        V_nn = model(Xinput)

    V_nn = [plotify(V) for V in V_nn]

    n_fields = len(V_nn) if type(V_nn) is list else 1
    n_plot = 1

    if fields_name is None:
        fields_name = V_exact.__name__.replace('_exact','') if V_exact is not None else 'V'

    coord = ["_x","_y","_xy"] if n_fields > 1 else [""]
    fields_name = [fields_name + coord[i] for i in range(n_fields)]

    if V_exact is not None:
        V_exact = V_exact(Xinput)
        V_exact = [plotify(V) for V in V_exact]
        n_plot = 3 if plot_diff else 2
        
    fig, ax = plt.subplots(n_fields, n_plot, figsize=(4*n_plot, 3*n_fields), dpi=dpi)

    for i in range(n_fields):
        subax = ax if n_fields == 1 else ax[i] 

        if V_exact is not None:

            cmax = max(V_nn[i].max(), V_exact[i].max())
            cmin = min(V_nn[i].min(), V_exact[i].min())

            im1 = pcolor_plot(subax[0], Xgrid, Ygrid, V_exact[i], f"{fields_name[i]}*", cmin=cmin, cmax=cmax)
            im2 = pcolor_plot(subax[1], Xgrid, Ygrid, V_nn[i], f"{fields_name[i]}_nn", cmin=cmin, cmax=cmax)

            fig.colorbar(im1, ax=subax[1])
        else:
            im1 = pcolor_plot(subax, Xgrid, Ygrid, V_nn[i], f"{fields_name[i]}_nn")
            fig.colorbar(im1, ax=subax)

        if plot_diff:
            diff = V_nn[i] - V_exact[i]
            abs_diff = np.abs(diff)
            cmax = abs_diff.max() if diff.max() > 0 else 0
            cmin = -abs_diff.max() if diff.min() < 0 else 0
            im3 = pcolor_plot(subax[2], Xgrid, Ygrid,diff, f"{fields_name[i]}_nn - {fields_name[i]}*", cmin=cmin, cmax=cmax, colormap="coolwarm")
            fig.colorbar(im3, ax=subax[2])
            subax[2].text(1.025,0.5,f"mean($\mid${fields_name[i]}_nn - {fields_name[i]}*$\mid$): {np.mean(abs_diff):.2e}", fontsize=6,ha = "center",rotation = "vertical",rotation_mode = "anchor",transform= subax[2].transAxes)

    return fig

# %%
domain = [[0, Lmax], [0, Lmax]]
U_plot = lambda x: U_nn(x, xi[0], Ux_mean, Ux_coeffs, Uy_mean, Uy_coeffs, Enforce_BC)
U_mean_plot = lambda x: U_nn(x, torch.zeros_like(xi[0]), Ux_mean, Ux_coeffs, Uy_mean, Uy_coeffs, Enforce_BC)
S_mean_plot = lambda x: S_nn(E_nn(U_mean_plot(x),x), np.exp(C11param[0]), np.exp(C33param[0]))

def U_std_plot(x):
    coeffs_x = [Enforce_BC(x,Ux_coeffs(x)[:,i],Uy_coeffs(x)[:,i])[0] for i in range(truncation_order)]
    coeffs_y = [Enforce_BC(x,Ux_coeffs(x)[:,i],Uy_coeffs(x)[:,i])[1] for i in range(truncation_order)]

    coeffs_x = torch.stack(coeffs_x,dim=1)
    coeffs_y = torch.stack(coeffs_y,dim=1)

    return [torch.sum(coeffs_x**2,dim=1)**0.5,torch.sum(coeffs_y**2,dim=1)**0.5]
        


# fig = plot_field(domain,U_mean_mc,V_exact=U_exact,plot_diff=True,fields_name="Umean_mc",N=28)
fig = plot_field(domain,U_mean_plot,V_exact=U_exact,plot_diff=True,fields_name="Umean")
# fig = plot_field(domain,U_mean_plot,fields_name="Umean")
# fig = plot_field(domain,S_mean_plot,fields_name="Smean")

# fig = plot_field(domain,U_std_mc,fields_name="Ustd",N=28)
fig = plot_field(domain,U_std_plot,V_exact=U_std_mc,plot_diff=True,fields_name="Ustd",N=28)
# fig = plot_field(domain,U_plot,V_exact=U_exact,plot_diff=True,fields_name="Usample")
